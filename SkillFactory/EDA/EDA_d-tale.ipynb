# %%
import pandas as pd
import dtale
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import dtale
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\dtale\__init__.py:24
#      21 LOCK_HEADER_MENU = False
#      23 # flake8: NOQA
# ---> 24 from dtale.app import show, get_instance, instances, offline_chart  # isort:skip
#      25 from dtale.cli.loaders import LOADERS  # isort:skip
#      26 from dtale.cli.clickutils import retrieve_meta_info_and_version
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\dtale\app.py:49
#      37 from dtale.cli.clickutils import retrieve_meta_info_and_version, setup_logging
#      38 from dtale.utils import (
#      39     DuplicateDataError,
# ...

# %%
df = pd.read_csv('wine.csv')
dtale.show(df)
