# %%
import pandas as pd
data = pd.read_csv('data\\autotochka.csv')

# %%
data
# Out:
#             Дата Время         Автомобиль  \
# 0  24.02.2023 21:51:00        Skoda Rapid
# 1  24.02.2023 21:59:00            Crysler
# 2  24.02.2023 22:02:00     Hyundai Porter
# 3  25.02.2023 22:02:00      Skoda Octavia
# 4  25.02.2023 22:04:00         Opel Corsa
# 5  25.02.2023 22:06:00        Kia Spectra
# 6  25.02.2023 22:08:00  Volkswagen Passat
# 7  25.02.2023 22:10:00       Toyota Prado
# 8  26.02.2023 12:06:00       Опель Вектра
#
#                                               Работы    Сумма  \
# 0                     Электротехнические работы 1500   1500,0
# 1  Диагностика генератора 1500, Ремонт генератора...   4500,0
# 2                              Ремонт эл.разъема 500    500,0
# 3  Компьютерная диагностика 1000, Электротехничес...   3000,0
# 4                                    Прошивка Евро-2  10000,0
# 5                      Компьютерная диагностика 1000   1000,0
# 6                     Электротехнические работы 2000   2000,0
# ...
