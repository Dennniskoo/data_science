# %%
import pandas as pd
data = pd.read_csv('cleared\\zakaz2022.csv')
data
# Out:
#       Unnamed: 0                                        Заказ наряд  \
# 0              0  Заказ-наряд №: 11 от 30.07.2021, ТС: Hyundai i...
# 1              1  Заказ-наряд №: 16 от 31.07.2021, ТС: ВАЗ 2109 ...
# 2              2  Заказ-наряд №: 18 от 31.07.2021, ТС: ВАЗ 2114 ...
# 3              3  Заказ-наряд №: 19 от 31.07.2021, ТС: Toyota Ca...
# 4              4  Заказ-наряд №: 20 от 31.07.2021, ТС: Hyundai S...
# ...          ...                                                ...
# 1512        1512  Заказ-наряд №: 8686 от 15.02.2023, ТС: Kia Rio...
# 1513        1513  Заказ-наряд №: 8689 от 16.02.2023, ТС: LADA VE...
# 1514        1514  Заказ-наряд №: 8704 от 17.02.2023, ТС: Самолет...
# 1515        1515  Заказ-наряд №: 8714 от 18.02.2023, ТС: Ravon R...
# 1516        1516  Заказ-наряд №: 8717 от 19.02.2023, ТС: Chevrol...
#
#             Дата  Цена                 ТС  Гос номер
# 0     2021-07-30  1700       Hyundai ix35  А681НС196
# ...

# %%
plot_data = data.groupby('ТС')['Цена'].describe()[['count', 'mean']].sort_values(by='mean', ascending=False)
plot_data[plot_data['count']>5]
# Средний чек по модели авто по 6 и более чекам
# Out:
#                       count         mean
# ТС
# Mitsubishi Pajero       6.0  4516.666667
# ГАЗ 2217                8.0  4350.000000
# Opel Corsa              6.0  3200.000000
# LADA 217230  PRIORA     6.0  3133.333333
# Hyundai Elantra         8.0  3125.000000
# Volkswagen Touareg      9.0  3072.222222
# Skoda Octavia           8.0  2768.750000
# LADA Granta             6.0  2683.333333
# Nissan X-Trail          8.0  2512.500000
# Nissan Note             6.0  2450.000000
# Ford Focus             14.0  2421.428571
# Opel Astra             19.0  2410.526316
# Nissan Teana            7.0  2385.714286
# Hyundai Solaris        22.0  2377.272727
# LADA  GRАNТА 219010    15.0  2326.666667
# Audi A6                 8.0  2312.500000
# Volkswagen Polo        18.0  2277.777778
# Kia Cerato              7.0  2128.571429
# Renault Duster          9.0  2122.222222
# Kia Sorento             8.0  2062.500000
# Toyota Camry           16.0  1981.250000
# Honda Accord            7.0  1957.142857
# ...
